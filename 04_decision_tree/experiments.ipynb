# %% [markdown]
# # <center>Decision Tree<center>

# %% [markdown]
# ---

# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ---

# %% [markdown]
# Importing data

# %% [markdown]
# ---

# %% [markdown]
# Checking data

# %% [markdown]
# ---

# %% [markdown]
# Visualizing data

# %% [markdown]
# ---
